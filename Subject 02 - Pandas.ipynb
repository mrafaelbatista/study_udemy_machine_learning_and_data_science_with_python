# %% [markdown]
# # Pandas

# %% [markdown]
# ## O que é o pandas?
#
# Pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language.

# %% [markdown]
# ## Instalação do Pandas
#
# <strong>PyPI</strong> <br />
# pip install pandas
#
# <strong>Conda</strong> <br />
# conda install pandas

# %%
# Importação do Pandas

import pandas as pd

# %% [markdown]
# ### Serie no Pandas

# %%
sample_serie = pd.Series([1,4,6,5,7,10,6])

# %%
print(sample_serie)
# Out:
# 0     1
# 1     4
# 2     6
# 3     5
# 4     7
# 5    10
# 6     6
# dtype: int64

# %%
sample_serie.describe()
# Out:
# count     7.000000
# mean      5.571429
# std       2.760262
# min       1.000000
# 25%       4.500000
# 50%       6.000000
# 75%       6.500000
# max      10.000000
# dtype: float64

# %%
df = pd.DataFrame([['Messias', 123456], ['Verônica', 789456], ['Miguel', 456789]])

# %%
df.shape
# Out:
# (3, 2)

# %%
df
# Out:
#           0       1
# 0   Messias  123456
# 1  Verônica  789456
# 2    Miguel  456789

# %%
df = pd.DataFrame([['Messias', 123456], ['Verônica', 789456], ['Miguel', 456789]],
                  columns=['nome', 'number'])

# %%
df
# Out:
#        nome  number
# 0   Messias  123456
# 1  Verônica  789456
# 2    Miguel  456789

# %%
df['nome']
# Out:
# 0     Messias
# 1    Verônica
# 2      Miguel
# Name: nome, dtype: object

# %%
df['number'].mean()
# Out:
# 456567.0

# %% [markdown]
# # PyDataset

# %%
import pydataset

# %%
pydataset.data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
titanic = pydataset.data('titanic')

# %%
titanic.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
titanic.tail()
# Out:
#           class    age    sex survived
# 1312  3rd class  child  women       no
# 1313  3rd class  child  women       no
# 1314  3rd class  child  women       no
# 1315  3rd class  child  women       no
# 1316  3rd class  child  women       no

# %%
titanic.describe()
# Out:
#             class     age   sex survived
# count        1316    1316  1316     1316
# unique          3       2     2        2
# top     3rd class  adults   man       no
# freq          706    1207   869      817

# %%
titanic['class'].value_counts()
# Out:
# 3rd class    706
# 1st class    325
# 2nd class    285
# Name: class, dtype: int64

# %%
len(pydataset.data())
# Out:
# 757

# %% [markdown]
# # DB.py
#
# É necessário pesquisar a lib para cada banco de dados e os parâmetros necessários para conectar o banco de dados.

# %%
from db import DB

# %%
database = DB(filename='./original/logs.sqlite3', dbtype='sqlite')
# Out:
# Indexing schema. This will take a second...finished!

# %%
database.tables
# Out:
# Refreshing schema. Please wait...done!
# +--------+-------+-------------------------+
# | Schema | Table | Columns                 |
# +--------+-------+-------------------------+
# | public | log   | id, path, user_id, date |
# +--------+-------+-------------------------+

# %%
log_df = database.tables.log

# %%
log_df
# Out:
# +---------------------------------------------------+
# |                        log                        |
# +---------+---------+--------------+----------------+
# | Column  | Type    | Foreign Keys | Reference Keys |
# +---------+---------+--------------+----------------+
# | id      | integer |              |                |
# | path    | text    |              |                |
# | user_id | integer |              |                |
# | date    | numeric |              |                |
# +---------+---------+--------------+----------------+

# %%
log_df = database.tables.log.all()

# %%
log_df
# Out:
#      id                  path  user_id                 date
# 0     1                     /        3  2017-01-03T11:41:00
# 1     2              /pandas/        4  2017-01-03T11:37:00
# 2     3              /videos/        5  2017-01-03T10:47:00
# 3     4                     /        2  2017-01-03T11:51:00
# 4     5  /python-para-zumbis/        5  2017-01-03T10:32:00
# 5     6              /cursos/        3  2017-01-03T11:31:00
# 6     7              /videos/        4  2017-01-03T10:39:00
# 7     8              /cursos/        5  2017-01-03T10:55:00
# 8     9                     /        4  2017-01-03T11:50:00
# 9    10              /pandas/        1  2017-01-03T11:38:00
# 10   11    /django-ecommerce/        5  2017-01-03T11:42:00
# 11   12                     /        4  2017-01-03T11:50:00
# 12   13    /django-ecommerce/        3  2017-01-03T11:59:00
# 13   14    /django-ecommerce/        4  2017-01-03T10:43:00
# 14   15  /python-para-zumbis/        5  2017-01-03T11:53:00
# 15   16              /cursos/        3  2017-01-03T11:39:00
# 16   17    /django-ecommerce/        5  2017-01-03T11:40:00
# 17   18  /python-para-zumbis/        5  2017-01-03T11:45:00
# 18   19              /pandas/        2  2017-01-03T11:36:00
# 19   20    /django-ecommerce/        2  2017-01-03T10:31:00
# 20   21              /videos/        2  2017-01-03T11:33:00
# 21   22    /django-ecommerce/        3  2017-01-03T10:35:00
# 22   23                     /        1  2017-01-03T11:56:00
# 23   24    /django-ecommerce/        4  2017-01-03T11:51:00
# 24   25              /cursos/        1  2017-01-03T10:54:00
# 25   26              /cursos/        4  2017-01-03T11:59:00
# 26   27  /python-para-zumbis/        2  2017-01-03T10:43:00
# 27   28    /django-ecommerce/        3  2017-01-03T11:57:00
# 28   29              /pandas/        1  2017-01-03T10:42:00
# 29   30              /cursos/        5  2017-01-03T10:57:00
# 30   31              /pandas/        2  2017-01-03T10:37:00
# 31   32    /django-ecommerce/        2  2017-01-03T10:51:00
# 32   33                     /        2  2017-01-03T10:42:00
# 33   34              /pandas/        3  2017-01-03T11:43:00
# 34   35              /videos/        4  2017-01-03T11:46:00
# 35   36  /python-para-zumbis/        5  2017-01-03T11:46:00
# 36   37                     /        5  2017-01-03T10:51:00
# 37   38              /videos/        3  2017-01-03T11:58:00
# 38   39    /django-ecommerce/        2  2017-01-03T11:37:00
# 39   40  /python-para-zumbis/        4  2017-01-03T11:31:00
# 40   41  /python-para-zumbis/        2  2017-01-03T11:48:00
# 41   42              /videos/        4  2017-01-03T11:37:00
# 42   43    /django-ecommerce/        1  2017-01-03T10:33:00
# 43   44              /cursos/        1  2017-01-03T10:57:00
# 44   45              /cursos/        4  2017-01-03T11:55:00
# 45   46                     /        5  2017-01-03T10:51:00
# 46   47              /pandas/        3  2017-01-03T10:55:00
# 47   48    /django-ecommerce/        4  2017-01-03T10:36:00
# 48   49              /videos/        2  2017-01-03T11:30:00
# 49   50                     /        4  2017-01-03T11:37:00
# 50   51  /python-para-zumbis/        3  2017-01-03T11:57:00
# 51   52    /django-ecommerce/        4  2017-01-03T10:46:00
# 52   53              /pandas/        2  2017-01-03T11:34:00
# 53   54              /videos/        1  2017-01-03T11:37:00
# 54   55                     /        1  2017-01-03T11:41:00
# 55   56                     /        3  2017-01-03T11:45:00
# 56   57  /python-para-zumbis/        5  2017-01-03T11:57:00
# 57   58              /cursos/        2  2017-01-03T10:31:00
# 58   59  /python-para-zumbis/        5  2017-01-03T10:36:00
# 59   60              /videos/        3  2017-01-03T11:37:00
# 60   61    /django-ecommerce/        4  2017-01-03T10:45:00
# 61   62    /django-ecommerce/        2  2017-01-03T10:59:00
# 62   63  /python-para-zumbis/        5  2017-01-03T11:46:00
# 63   64                     /        3  2017-01-03T10:48:00
# 64   65    /django-ecommerce/        5  2017-01-03T11:51:00
# 65   66    /django-ecommerce/        3  2017-01-03T10:54:00
# 66   67                     /        4  2017-01-03T11:31:00
# 67   68              /cursos/        5  2017-01-03T10:47:00
# 68   69  /python-para-zumbis/        3  2017-01-03T11:50:00
# 69   70              /pandas/        5  2017-01-03T10:38:00
# 70   71              /videos/        1  2017-01-03T11:50:00
# 71   72              /videos/        5  2017-01-03T11:59:00
# 72   73                     /        3  2017-01-03T11:49:00
# 73   74                     /        2  2017-01-03T11:34:00
# 74   75              /pandas/        4  2017-01-03T11:35:00
# 75   76              /pandas/        1  2017-01-03T11:48:00
# 76   77              /pandas/        2  2017-01-03T11:35:00
# 77   78  /python-para-zumbis/        3  2017-01-03T11:54:00
# 78   79              /pandas/        3  2017-01-03T11:57:00
# 79   80              /videos/        3  2017-01-03T11:32:00
# 80   81              /pandas/        2  2017-01-03T10:36:00
# 81   82    /django-ecommerce/        3  2017-01-03T11:39:00
# 82   83              /pandas/        3  2017-01-03T11:51:00
# 83   84              /videos/        1  2017-01-03T11:51:00
# 84   85    /django-ecommerce/        3  2017-01-03T10:45:00
# 85   86              /videos/        4  2017-01-03T11:59:00
# 86   87              /cursos/        2  2017-01-03T10:47:00
# 87   88                     /        5  2017-01-03T11:56:00
# 88   89  /python-para-zumbis/        1  2017-01-03T11:34:00
# 89   90  /python-para-zumbis/        2  2017-01-03T11:35:00
# 90   91              /pandas/        2  2017-01-03T11:33:00
# 91   92  /python-para-zumbis/        1  2017-01-03T11:33:00
# 92   93              /videos/        2  2017-01-03T11:59:00
# 93   94    /django-ecommerce/        3  2017-01-03T11:54:00
# 94   95              /pandas/        2  2017-01-03T11:39:00
# 95   96    /django-ecommerce/        1  2017-01-03T10:49:00
# 96   97                     /        5  2017-01-03T10:33:00
# 97   98              /cursos/        5  2017-01-03T10:31:00
# 98   99  /python-para-zumbis/        3  2017-01-03T10:56:00
# 99  100              /cursos/        4  2017-01-03T11:46:00

# %%
log_df = database.query('select * from log where user_id = 3')

# %%
log_df
# Out:
#     id                  path  user_id                 date
# 0    1                     /        3  2017-01-03T11:41:00
# 1    6              /cursos/        3  2017-01-03T11:31:00
# 2   13    /django-ecommerce/        3  2017-01-03T11:59:00
# 3   16              /cursos/        3  2017-01-03T11:39:00
# 4   22    /django-ecommerce/        3  2017-01-03T10:35:00
# 5   28    /django-ecommerce/        3  2017-01-03T11:57:00
# 6   34              /pandas/        3  2017-01-03T11:43:00
# 7   38              /videos/        3  2017-01-03T11:58:00
# 8   47              /pandas/        3  2017-01-03T10:55:00
# 9   51  /python-para-zumbis/        3  2017-01-03T11:57:00
# 10  56                     /        3  2017-01-03T11:45:00
# 11  60              /videos/        3  2017-01-03T11:37:00
# 12  64                     /        3  2017-01-03T10:48:00
# 13  66    /django-ecommerce/        3  2017-01-03T10:54:00
# 14  69  /python-para-zumbis/        3  2017-01-03T11:50:00
# 15  73                     /        3  2017-01-03T11:49:00
# 16  78  /python-para-zumbis/        3  2017-01-03T11:54:00
# 17  79              /pandas/        3  2017-01-03T11:57:00
# 18  80              /videos/        3  2017-01-03T11:32:00
# 19  82    /django-ecommerce/        3  2017-01-03T11:39:00
# 20  83              /pandas/        3  2017-01-03T11:51:00
# 21  85    /django-ecommerce/        3  2017-01-03T10:45:00
# 22  94    /django-ecommerce/        3  2017-01-03T11:54:00
# 23  99  /python-para-zumbis/        3  2017-01-03T10:56:00

# %% [markdown]
# Possibilidade de usar um arquivo sql
#
# log_df = database.query_from_file('arquivo.sql')

# %%
log_df = database.query('select * from log')

# %%
len(log_df)
# Out:
# 100

# %% [markdown]
# # Carregar Planilhas de Dados para o Pandas

# %%
# Carregar o CSV
copacabana = pd.read_csv('./original/copacabana.csv', delimiter=';')

# %%
copacabana.head()
# Out:
#    Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 0        1      3.0   0.01         1144        311         146      969501
# 1        0      2.0   0.01         2456        502         254     1472861
# 2        0      2.0   0.01         2448        772         229     1803724
# 3        0      2.0   0.01         1615        428         310     1124331
# 4        0      2.0   1.00         2358        586         287     1165764
#
#    RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 0     1028834         999168    1750  509   37.0          1              95
# 1     1137759        1305310    2300  484   30.0          1              71
# 2     1512475        1658100    2350  920   44.0          1              58
# 3     1370600        1247466    2200  930   43.0          1              88
# 4     1177933        1171849    2150  918   42.0          1              68
#
#    VAL_UNIT            X            Y
# 0      4379  685365.0700  7457802.680
# 1      6479  685941.5500  7459001.320
# 2     12414  685627.3900  7459080.520
# 3     11250  685438.2001  7458268.280
# 4     13382  685764.3840  7458954.513

# %%
populacao_pe = pd.read_excel('./original/total_populacao_pernambuco.xls')

# %%
populacao_pe.head()
# Out:
#   Código do município      Nome do município  Total da população 2000  \
# 0             2600054           Abreu e Lima                  89039.0
# 1             2600104  Afogados da Ingazeira                  32922.0
# 2             2600203                Afrânio                  15014.0
# 3             2600302              Agrestina                  20036.0
# 4             2600401             Água Preta                  28531.0
#
#    Total de homens  Total de mulheres  Total da população urbana  \
# 0          45165.0            49263.0                    86589.0
# 1          16790.0            18301.0                    27406.0
# 2           8751.0             8837.0                     5859.0
# 3          10938.0            11742.0                    16955.0
# 4          16581.0            16465.0                    18708.0
#
#    Total da população rural  Total da população 2010
# 0                    7839.0                  94428.0
# 1                    7685.0                  35091.0
# 2                   11729.0                  17588.0
# 3                    5725.0                  22680.0
# 4                   14338.0                  33046.0

# %% [markdown]
# ### Realizando Filtros / Seleção em Dataframe

# %%
copacabana.columns
# Out:
# Index(['Posicao', 'Quartos', 'Vagas', 'DistIpanema', 'DistPraia', 'DistFavela',
#        'RendaMedia', 'RendaMovel', 'RendaMovelRua', 'Vu2009', 'Mes', 'Idade',
#        'Tipologia', 'AreaConstruida', 'VAL_UNIT', 'X', 'Y'],
#       dtype='object')

# %%
copacabana['Quartos'].describe()
# Out:
# count    1675.000000
# mean        1.767510
# std         1.142523
# min         0.010000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: Quartos, dtype: float64

# %%
copacabana.loc[copacabana['Quartos'] == 6]
# Out:
#      Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 748        1      6.0    2.0         2500         35         743     1524600
#
#      RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  AreaConstruida  \
# 748     1275377        1399989    4100  360   58.0          1             668
#
#      VAL_UNIT          X           Y
# 748      4491  686456.25  7458801.05

# %%
copacabana.loc[copacabana['Quartos'] == 5]
# Out:
#       Posicao  Quartos  Vagas  DistIpanema  DistPraia  DistFavela  RendaMedia  \
# 173         1      5.0   0.01         2696        154         712     1083455
# 1521        1      5.0   3.00         3044         31         609     1524600
#
#       RendaMovel  RendaMovelRua  Vu2009  Mes  Idade  Tipologia  \
# 173       649733         866594    2000  425   55.0          1
# 1521     1168222        1346411    4100  405   34.0          1
#
#       AreaConstruida  VAL_UNIT            X           Y
# 173               38      6316  686522.9800  7458989.87
# 1521             430      5000  686965.3201  7459109.71

# %% [markdown]
# ## Dados Categóricos
#
# Tipos de dados por colunas

# %%
titanic.columns
# Out:
# Index(['class', 'age', 'sex', 'survived'], dtype='object')

# %%
titanic['class'].describe()
# Out:
# count          1316
# unique            3
# top       3rd class
# freq            706
# Name: class, dtype: object

# %%
titanic['class'].nbytes
# Out:
# 10528

# %%
# %%time
titanic['class'] == '3rd class'
# Out:
# Wall time: 4.01 ms
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1312     True
# 1313     True
# 1314     True
# 1315     True
# 1316     True
# Name: class, Length: 1316, dtype: bool

# %%
# transformando para dados categóricos
titanic['class'] = titanic['class'].astype('category')

# %%
# verificando que os tipos de dados continuam o mesmo
titanic['class'].describe()
# Out:
# count          1316
# unique            3
# top       3rd class
# freq            706
# Name: class, dtype: object

# %%
# a quantidade de bytes utilizados diminuiu
titanic['class'].nbytes
# Out:
# 1340

# %%
# %%time
titanic['class'] == '3rd class'
# Out:
# Wall time: 929 µs
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1312     True
# 1313     True
# 1314     True
# 1315     True
# 1316     True
# Name: class, Length: 1316, dtype: bool

# %% [markdown]
# ## Problemas de Dados Perdidos (data missing)
#
# Utilizaremos Pandas e Numpy.
#
# Essa técnica consiste em consertar conjuntos de dados que por ventura tenham perdido alguma informação durante o processo de coleta.

# %%
import numpy as np

# %%
dados = {
    'nome' : ['João', 'Maria', 'José', np.nan, 'Pedro', 'Judas', 'Tiago'],
    'sexo' : ['M', 'F', 'M', np.nan, 'M', 'M', np.nan],
    'idade' : [14, 13, np.nan, np.nan, 15, 13, 14],
    'nota' : [4, 10, 7, np.nan, 8, 9, 7]
}

df = pd.DataFrame(dados)

# %%
df
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 3    NaN  NaN    NaN   NaN
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
# estratégia para dropar todas as linhas que tem pelo menos
# um dado incompleto

df.dropna()
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0

# %%
# dropa as linhas na qual todos os dados são incompletos

df.dropna(how='all')
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
df['serie'] = np.nan

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 3    NaN  NaN    NaN   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
# dropa as linhas na qual todos os dados são incompletos
# alterando para o AXIS 1 o pandas verifica a coluna e não a linha

df.dropna(how='all', axis=1)
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 3    NaN  NaN    NaN   NaN
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
# também podemos informar a quantidade de dados perdidas na linha

df.dropna(thresh=3)
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
# Estratégia de preencher os valores perdidos com algum valor.

# Atenção - Essa alteração será apenas apresentada. Ela não altera
# o dataset

df['serie'].fillna(8)
# Out:
# 0    8.0
# 1    8.0
# 2    8.0
# 3    8.0
# 4    8.0
# 5    8.0
# 6    8.0
# Name: serie, dtype: float64

# %%
# Para alterar o dataset, utilize o código abaixo

df['serie'].fillna(8, inplace=True)

# %%
df['serie'] = np.nan
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 3    NaN  NaN    NaN   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
# Estratégia de preencger com a média

df['idade'].fillna(df['idade'].mean(), inplace=True)

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M   13.8   7.0    NaN
# 3    NaN  NaN   13.8   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
# Estratégia utilizando filtros

df[df['nome'].notnull() & df['sexo'].notnull()]
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M   13.8   7.0    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
